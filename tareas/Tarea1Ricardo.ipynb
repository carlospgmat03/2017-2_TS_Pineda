# %% [markdown]
# # Logistic map

# %%
##Se avisa que se usara PyPlot##

# %%
using PyPlot

# %%
#Se le da nombre a la gráfica y a sus ejes#

# %%
x=PyPlot.figure("Diagram")
PyPlot.subplot()
xlabel("r")
ylabel("x")
title("Diagrama de Bifurcación")

#la variable r va de 0 a 4 pero en este caso iniciamos de 2.7 para agiizar el proceso#

for r in 2.7:0.005:4.00 
   for x in 0.00:0.005:1
        
      for i in 1:900     # i es una variable auxiliar que no se presenta en el cálculo.
        x = r*x*(1-x);    
            end         # imprimimos los puntos r,x cada que finaliza un cálculo
        PyPlot.scatter(r,x,s=0.003, c="black")
    end
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fda3c8be9d0>)
